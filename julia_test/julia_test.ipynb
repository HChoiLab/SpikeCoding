# %%
import Pkg

# %%
try
    @eval import MAT
    println("MAT is installed")
catch
    println("MAT is not installed. Installing now...")
    Pkg.add("MAT")
    @eval import MAT
end

try
    @eval import DelimitedFiles
    println("DelimitedFiles is installed")
catch
    println("DelimitedFiles is not installed. Installing now...")
    Pkg.add("DelimitedFiles")
    @eval import DelimitedFiles
end

try
    @eval import Plots
    println("Plots is installed")
catch
    println("Plots is not installed. Installing now...")
    Pkg.add("Plots")
    @eval import Plots
end

try
    @eval import CausalityTools
    println("CausalityTools is installed")
catch
    println("CausalityTools is not installed. Installing now...")
    Pkg.add("CausalityTools")
    @eval import CausalityTools
end

try
    @eval import LIBSVM
    println("LIBSVM is installed")
catch
    println("LIBSVM is not installed. Installing now...")
    Pkg.add("LIBSVM")
    @eval import LIBSVM
end

try
    @eval import ScikitLearn
    println("ScikitLearn is installed")
catch
    println("ScikitLearn is not installed. Installing now...")
    Pkg.add("ScikitLearn")
    @eval import ScikitLearn
end

try
    @eval import LaTeXStrings
    println("LaTeXStrings is installed")
catch
    println("LaTeXStrings is not installed. Installing now...")
    Pkg.add("LaTeXStrings")
    @eval import LaTeXStrings
end

try
    @eval import Metrics
    println("Metrics is installed")
catch
    println("Metrics is not installed. Installing now...")
    Pkg.add("Metrics")
    @eval import Metrics
end

try
    @eval import Statistics
    println("Statistics is installed")
catch
    println("Statistics is not installed. Installing now...")
    Pkg.add("Statistics")
    @eval import Statistics
end

try
    @eval import PyCall
    println("PyCall is installed")
catch
    println("PyCall is not installed. Installing now...")
    Pkg.add("PyCall")
    @eval import PyCall
end

try
    @eval import PyPlot
    println("PyPlot is installed")
catch
    println("PyPlot is not installed. Installing now...")
    Pkg.add("PyPlot")
    @eval import PyPlot
end

try
    @eval import Distributions
    println("Distributions is installed")
catch
    println("Distributions is not installed. Installing now...")
    Pkg.add("Distributions")
    @eval import Distributions
end

try
    @eval import Random
    println("Random is installed")
catch
    println("Random is not installed. Installing now...")
    Pkg.add("Random")
    @eval import Random
end

try
    @eval import Printf
    println("Printf is installed")
catch
    println("Printf is not installed. Installing now...")
    Pkg.add("Printf")
    @eval import Printf
end

try
    @eval import NPZ
    println("NPZ is installed")
catch
    println("NPZ is not installed. Installing now...")
    Pkg.add("NPZ")
    @eval import NPZ
end
# Out:
# MAT is installed
# DelimitedFiles is installed
# Plots is installed
# CausalityTools is installed
# LIBSVM is not installed. Installing now...
#    Resolving package versions...
#    Installed liblinear_jll ─ v2.47.0+0
#    Installed LIBLINEAR ───── v0.7.0
#    Installed LIBSVM ──────── v0.8.1
#     Updating `C:\Users\zdm42\.julia\environments\v1.10\Project.toml`
#   [b1bec4e5] + LIBSVM v0.8.1
#     Updating `C:\Users\zdm42\.julia\environments\v1.10\Manifest.toml`
#   [2d691ee1] + LIBLINEAR v0.7.0
#   [b1bec4e5] + LIBSVM v0.8.1
#   [6e75b9c4] + ScikitLearnBase v0.5.0
#   [275f1f90] + liblinear_jll v2.47.0+0
#   [08558c22] + libsvm_jll v3.25.0+0
# Precompiling project...
#   ✓ libsvm_jll
#   ✓ liblinear_jll
#   ✓ ScikitLearnBase
#   ✓ LIBLINEAR
#   ✓ LIBSVM
#   5 dependencies successfully precompiled in 5 seconds. 379 already precompiled.
# ScikitLearn is not installed. Installing now...
#    Resolving package versions...
#    Installed SentinelArrays ─ v1.4.5
#    Installed InlineStrings ── v1.4.2
#    Installed PyCall ───────── v1.96.4
#    Installed PrettyTables ─── v2.3.2
#     Updating `C:\Users\zdm42\.julia\environments\v1.10\Project.toml`
#   [3646fa90] + ScikitLearn v0.7.0
#     Updating `C:\Users\zdm42\.julia\environments\v1.10\Manifest.toml`
#   [a93c6f00] + DataFrames v1.6.1
#   [842dd82b] + InlineStrings v1.4.2
#   [41ab1584] + InvertedIndices v1.3.0
#   [2dfb63ee] + PooledArrays v1.4.3
#   [08abe8d2] + PrettyTables v2.3.2
#   [438e738f] + PyCall v1.96.4
#   [3646fa90] + ScikitLearn v0.7.0
#   [91c51154] + SentinelArrays v1.4.5
# ⌅ [2913bbd2] ↓ StatsBase v0.34.3 ⇒ v0.33.21
#   [892a3eda] + StringManipulation v0.3.4
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
#     Building PyCall → `C:\Users\zdm42\.julia\scratchspaces\44cfe95a-1eb2-52ea-b672-e2afdf69b78f\9816a3826b0ebf49ab4926e2b18842ad8b5c8f04\build.log`
# Precompiling project...
#   ✓ InvertedIndices
#   ✓ PooledArrays
#   ✓ InlineStrings
#   ✓ InlineStrings → ParsersExt
#   ✓ SentinelArrays
#   ✓ StringManipulation
#   ✓ StatsBase
#   ✓ PyCall
#   ✓ SciMLBase → SciMLBasePyCallExt
#   ✓ PrettyTables
#   ✓ DataFrames
#   ✓ Latexify → DataFramesExt
#   ✓ ScikitLearn
#   13 dependencies successfully precompiled in 121 seconds. 383 already precompiled.
#   1 dependency precompiled but a different version is currently loaded. Restart julia to access the new version
# [ Info: Precompiling ScikitLearn [3646fa90-6ef7-5e7e-9f22-8aca16db6324]
# LaTeXStrings is not installed. Installing now...
#    Resolving package versions...
#     Updating `C:\Users\zdm42\.julia\environments\v1.10\Project.toml`
#   [b964fa9f] + LaTeXStrings v1.3.1
#   No Changes to `C:\Users\zdm42\.julia\environments\v1.10\Manifest.toml`
# Metrics is not installed. Installing now...
#    Resolving package versions...
#     Updating `C:\Users\zdm42\.julia\environments\v1.10\Project.toml`
#   [cb9f3049] + Metrics v0.1.2
#     Updating `C:\Users\zdm42\.julia\environments\v1.10\Manifest.toml`
#   [cb9f3049] + Metrics v0.1.2
# Precompiling project...
#   ? Metrics
# Precompiling Metrics
#         Info Given Metrics was explicitly requested, output will be shown live
# WARNING: Method definition onehot_encode(Any, Any) in module Metrics at C:\Users\zdm42\.julia\packages\Metrics\giLga\src\Classification.jl:5 overwritten on the same line (check for duplicate calls to `include`).
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#   ? Metrics
# [ Info: Precompiling Metrics [cb9f3049-315b-4f05-b90c-a8adaec4da78]
# WARNING: Method definition onehot_encode(Any, Any) in module Metrics at C:\Users\zdm42\.julia\packages\Metrics\giLga\src\Classification.jl:5 overwritten on the same line (check for duplicate calls to `include`).
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# [ Info: Skipping precompilation since __precompile__(false). Importing Metrics [cb9f3049-315b-4f05-b90c-a8adaec4da78].
# Statistics is installed
# PyCall is not installed. Installing now...
# ┌ Warning: Replacing docs for `Metrics.bin_to_cat :: Tuple{Any, Any}` in module `Metrics`
# └ @ Base.Docs docs\Docs.jl:243
# ┌ Warning: Replacing docs for `Metrics.confusion_matrix :: Tuple{Any, Any}` in module `Metrics`
# └ @ Base.Docs docs\Docs.jl:243
# ┌ Warning: Replacing docs for `Metrics.TFPN :: Tuple{Any, Any}` in module `Metrics`
# └ @ Base.Docs docs\Docs.jl:243
# ┌ Warning: Replacing docs for `Metrics.binary_accuracy :: Tuple{Any, Any}` in module `Metrics`
# └ @ Base.Docs docs\Docs.jl:243
# ┌ Warning: Replacing docs for `Metrics.categorical_accuracy :: Tuple{Any, Any}` in module `Metrics`
# └ @ Base.Docs docs\Docs.jl:243
# ┌ Warning: Replacing docs for `Metrics.sparse_categorical :: Tuple{Any, Any}` in module `Metrics`
# └ @ Base.Docs docs\Docs.jl:243
# ┌ Warning: Replacing docs for `Metrics.top_k_categorical :: Tuple{Any, Any}` in module `Metrics`
# └ @ Base.Docs docs\Docs.jl:243
# ┌ Warning: Replacing docs for `Metrics.top_k_sparse_categorical :: Tuple{Any, Any}` in module `Metrics`
# └ @ Base.Docs docs\Docs.jl:243
# ┌ Warning: Replacing docs for `Metrics.precision :: Tuple{Any, Any}` in module `Metrics`
# └ @ Base.Docs docs\Docs.jl:243
# ┌ Warning: Replacing docs for `Metrics.recall :: Tuple{Any, Any}` in module `Metrics`
# └ @ Base.Docs docs\Docs.jl:243
# ┌ Warning: Replacing docs for `Metrics.f_beta_score :: Tuple{Any, Any}` in module `Metrics`
# └ @ Base.Docs docs\Docs.jl:243
# ┌ Warning: Replacing docs for `Metrics.specificity :: Tuple{Any, Any}` in module `Metrics`
# └ @ Base.Docs docs\Docs.jl:243
# ┌ Warning: Replacing docs for `Metrics.false_alarm_rate :: Tuple{Any, Any}` in module `Metrics`
# └ @ Base.Docs docs\Docs.jl:243
# ┌ Warning: Replacing docs for `Metrics.cohen_kappa :: Tuple{Any, Any}` in module `Metrics`
# └ @ Base.Docs docs\Docs.jl:243
# ┌ Warning: Replacing docs for `Metrics.statsfromTFPN :: NTuple{4, Any}` in module `Metrics`
# └ @ Base.Docs docs\Docs.jl:243
# ┌ Warning: Replacing docs for `Metrics.classwise_stats_fn :: Tuple{Any, Any}` in module `Metrics`
# └ @ Base.Docs docs\Docs.jl:243
# ┌ Warning: Replacing docs for `Metrics.global_stats :: Tuple{Any, Any}` in module `Metrics`
# └ @ Base.Docs docs\Docs.jl:243
#    Resolving package versions...
#     Updating `C:\Users\zdm42\.julia\environments\v1.10\Project.toml`
#   [438e738f] + PyCall v1.96.4
#   No Changes to `C:\Users\zdm42\.julia\environments\v1.10\Manifest.toml`
# Precompiling project...
# PyPlot is not installed. Installing now...
#   ? Metrics
#    Resolving package versions...
#    Installed PyPlot ─ v2.11.5
#     Updating `C:\Users\zdm42\.julia\environments\v1.10\Project.toml`
#   [d330b81b] + PyPlot v2.11.5
#     Updating `C:\Users\zdm42\.julia\environments\v1.10\Manifest.toml`
#   [d330b81b] + PyPlot v2.11.5
# Precompiling project...
#   ? Metrics
#   ✓ PyPlot
#   1 dependency successfully precompiled in 4 seconds. 396 already precompiled.
#   1 dependency precompiled but a different version is currently loaded. Restart julia to access the new version
#   1 dependency failed but may be precompilable after restarting julia
#   1 dependency had output during precompilation:
# ┌ Metrics
# │  WARNING: Method definition onehot_encode(Any, Any) in module Metrics at C:\Users\zdm42\.julia\packages\Metrics\giLga\src\Classification.jl:5 overwritten on the same line (check for duplicate calls to `include`).
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# Distributions is not installed. Installing now...
#    Resolving package versions...
#     Updating `C:\Users\zdm42\.julia\environments\v1.10\Project.toml`
#   [31c24e10] + Distributions v0.25.109
#   No Changes to `C:\Users\zdm42\.julia\environments\v1.10\Manifest.toml`
# Precompiling project...
#   ? Metrics
# Random is installed
# Printf is installed
# NPZ is not installed. Installing now...
#    Resolving package versions...
#    Installed ZipFile ─ v0.10.1
#    Installed NPZ ───── v0.4.3
#    Installed FileIO ── v1.16.3
#     Updating `C:\Users\zdm42\.julia\environments\v1.10\Project.toml`
#   [15e1cf62] + NPZ v0.4.3
#     Updating `C:\Users\zdm42\.julia\environments\v1.10\Manifest.toml`
#   [5789e2e9] + FileIO v1.16.3
#   [15e1cf62] + NPZ v0.4.3
#   [a5390f91] + ZipFile v0.10.1
# Precompiling project...
#   ✓ ZipFile
#   ? Metrics
#   ✓ FileIO
#   ✓ NPZ
#   ✓ Plots → FileIOExt
#   4 dependencies successfully precompiled in 127 seconds. 397 already precompiled.
#   1 dependency precompiled but a different version is currently loaded. Restart julia to access the new version
#   1 dependency failed but may be precompilable after restarting julia
#   1 dependency had output during precompilation:
# ┌ Metrics
# │  WARNING: Method definition onehot_encode(Any, Any) in module Metrics at C:\Users\zdm42\.julia\packages\Metrics\giLga\src\Classification.jl:5 overwritten on the same line (check for duplicate calls to `include`).
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# [ Info: Precompiling FileIOExt [f5f51d8f-5827-5d2e-939b-192fcd6ec70c]

# %%
using MAT
using DelimitedFiles
using Plots
using CausalityTools
using LIBSVM
using ScikitLearn
using LaTeXStrings
using Metrics
using Statistics
using PyCall
np = pyimport("numpy")
using PyPlot
const plt = PyPlot;
using Distributions, Random
using Printf
using NPZ
