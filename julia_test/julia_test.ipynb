# %%
import Pkg

# %%
try
    @eval import MAT
    println("MAT is installed")
catch
    println("MAT is not installed. Installing now...")
    Pkg.add("MAT")
    @eval import MAT
end

try
    @eval import DelimitedFiles
    println("DelimitedFiles is installed")
catch
    println("DelimitedFiles is not installed. Installing now...")
    Pkg.add("DelimitedFiles")
    @eval import DelimitedFiles
end

try
    @eval import StatsBase
    println("StatsBase is installed")
catch
    println("StatsBase is not installed. Installing now...")
    Pkg.add("StatsBase")
    @eval import StatsBase
end

# try
#     @eval import Plots
#     println("Plots is installed")
# catch
#     println("Plots is not installed. Installing now...")
#     Pkg.add("Plots")
#     @eval import Plots
# end

try
    @eval import CausalityTools
    println("CausalityTools is installed")
catch
    println("CausalityTools is not installed. Installing now...")
    Pkg.add("CausalityTools")
    @eval import CausalityTools
end

# try
#     @eval import LIBSVM
#     println("LIBSVM is installed")
# catch
#     println("LIBSVM is not installed. Installing now...")
#     Pkg.add("LIBSVM")
#     @eval import LIBSVM
# end

# try
#     @eval import ScikitLearn
#     println("ScikitLearn is installed")
# catch
#     println("ScikitLearn is not installed. Installing now...")
#     Pkg.add("ScikitLearn")
#     @eval import ScikitLearn
# end

# try
#     @eval import LaTeXStrings
#     println("LaTeXStrings is installed")
# catch
#     println("LaTeXStrings is not installed. Installing now...")
#     Pkg.add("LaTeXStrings")
#     @eval import LaTeXStrings
# end

# try
#     @eval import Metrics
#     println("Metrics is installed")
# catch
#     println("Metrics is not installed. Installing now...")
#     Pkg.add("Metrics")
#     @eval import Metrics
# end

# try
#     @eval import Statistics
#     println("Statistics is installed")
# catch
#     println("Statistics is not installed. Installing now...")
#     Pkg.add("Statistics")
#     @eval import Statistics
# end

try
    @eval import PyCall
    println("PyCall is installed")
catch
    println("PyCall is not installed. Installing now...")
    Pkg.add("PyCall")
    @eval import PyCall
end

try
    @eval import PyPlot
    println("PyPlot is installed")
catch
    println("PyPlot is not installed. Installing now...")
    Pkg.add("PyPlot")
    @eval import PyPlot
end

try
    @eval import Distributions
    println("Distributions is installed")
catch
    println("Distributions is not installed. Installing now...")
    Pkg.add("Distributions")
    @eval import Distributions
end

try
    @eval import Random
    println("Random is installed")
catch
    println("Random is not installed. Installing now...")
    Pkg.add("Random")
    @eval import Random
end

# try
#     @eval import Printf
#     println("Printf is installed")
# catch
#     println("Printf is not installed. Installing now...")
#     Pkg.add("Printf")
#     @eval import Printf
# end

try
    @eval import NPZ
    println("NPZ is installed")
catch
    println("NPZ is not installed. Installing now...")
    Pkg.add("NPZ")
    @eval import NPZ
end
# Out:
# MAT is installed
# DelimitedFiles is installed
# CausalityTools is installed
# PyCall is installed
# PyPlot is not installed. Installing now...
# /storage/home/hcoda1/8/zmobille3/.local/lib/python3.9/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
#    Resolving package versions...
#   No Changes to `/storage/coda1/p-hchoi387/0/zmobille3/.julia/environments/v1.9/Project.toml`
#   No Changes to `/storage/coda1/p-hchoi387/0/zmobille3/.julia/environments/v1.9/Manifest.toml`
# Distributions is installed
# Random is installed
# NPZ is installed

# %%
using MAT
using DelimitedFiles
# using Plots
using CausalityTools
# using LIBSVM
# using ScikitLearn
# using LaTeXStrings
# using Metrics
# using Statistics
using PyCall
np = pyimport("numpy")
using PyPlot
const plt = PyPlot;
using Distributions, Random
# using Printf
using NPZ
